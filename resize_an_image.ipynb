# %% [markdown]
# <a href="https://colab.research.google.com/github/Monishri879/image-processing/blob/main/resize_an_image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow
image=cv2.imread('/content/moo.png')
print("Original image")
cv2_imshow(image)

resize=cv2.resize(image,(300,400))
print("Resized image")
cv2_imshow(resize)
# Out:
# Original image
# <PIL.Image.Image image mode=RGB size=724x481>
# Resized image
# <PIL.Image.Image image mode=RGB size=300x400>
